# %%
import ee
import geemap
import os
from datetime import datetime

# %%
# Configuración de variables

Coleccion = "IDAHO_EPSCOR/TERRACLIMATE"
geometry = "users/leofabiop120/Chile/Malla_1km_y_Comuna_Chile_GCS"
estadistica = "MEAN"
nombreEstadistica = "MEDIA"
escala = 500
startDate = "2001-01-01"
rutaDescarga = "descarga"

# %%
def DescargaDatos():
    
    rango1 = []

    inicial = 720000
    final = 730001
    
    for i in range(4):
        print(i + 1)
        
        Map = geemap.Map()
        landcoverColection = ee.ImageCollection(Coleccion)

        fecha_inicio = startDate
        fecha_final = "2020-01-01"
        # fecha_final = datetime.now().strftime("%Y-%m-%d")

        limites = ee.FeatureCollection(geometry)

        rango1 = inicial
        rango2 = final

        mallaFiltro = limites.filterMetadata("Parcela_ID", "greater_than", rango1) \
                                .filterMetadata("Parcela_ID", "less_than", rango2)

        out_dir = os.path.join(rutaDescarga)
        if not os.path.exists(out_dir):
            os.makedirs(out_dir)
        nombre_archivo = Coleccion.split("/")[1]

        for band in landcoverColection.first().bandNames().getInfo():
            print(f"Descargando los datos de {estadistica} correspondiente a la banda {band}")
            landcover = landcoverColection.select(band).filter(ee.Filter.date(fecha_inicio, fecha_final))
            out_dem_stats = os.path.join(out_dir, f'{nombre_archivo}_{nombreEstadistica}_{band}_{rango1+1}_{rango2-1}.csv')
            geemap.zonal_statistics(landcover, mallaFiltro, out_dem_stats, statistics_type=estadistica, scale=escala)
        # return nombre_archivo
        
        inicial = final - 1
        final += 10000

# %%
DescargaDatos()
# Out:
# 1
# Descargando los datos de MEAN correspondiente a la banda aet
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/cbb6b050eee7e34d45f4c55e4b1bc2c4-bc272282e71932944643593df22609a2:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_aet_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda def
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/7d63b3e55fabf5c2155cefd7dc18ef85-5a88cc2bd5709010e02fa268ba04167d:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_def_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda pdsi
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/bfcadb0e48016ba1a9fcdf74dc375b50-a0c087aafa166b7ba0c509d1435bc59d:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_pdsi_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda pet
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/aa53c0ae66d15a422a207d28903f847a-0bb0d93d3ffa2dd2ef8b528c00cbb7ee:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_pet_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda pr
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/6e066cc757555f6f3f8145eef97db168-000660d6b4ae519a5c19fce389c8be09:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_pr_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda ro
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/d41431775ae2e7f46437c3fd09af2067-660fa896cd2f4d3ff3cf8aa10d7f15d1:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_ro_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda soil
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/f8edee553352546e3fe5631743c97373-d0fe12b1c4e1b01361846d609babac3c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_soil_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda srad
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/7b1ca0d4eea2db30310cfcaba97a6695-056f31b39c8ace4b778d1f590debb81b:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_srad_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda swe
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/9135f8b5454587982746c27b346e0360-adad1c4a70e069abe2c7c09ed7d18fc1:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_swe_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda tmmn
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/41014347e4447d706b922de7e7017268-5ab632d2a2af912a09bf9e557a2502e8:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_tmmn_720001_730000.csv
# Descargando los datos de MEAN correspondiente a la banda tmmx
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/bfc4e3b77e99ecad1f1fd0060b99f346-ed1cccf379b08b7f9d8a1467be611b12:getFeatures
# Please wait ...
# Data downloaded to C:\Users\Hector\Desktop\DI\Notebooks\descarga_malla_puntos_terraclimate\descarga\TERRACLIMATE_MEDIA_tm